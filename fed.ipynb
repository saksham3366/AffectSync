# %%
import os
import random
import matplotlib.pyplot as plt 
from PIL import Image

# %%
train_images = "fer/train"
train_iamges_classes = os.listdir(train_images)

# %%
img = Image.open("fer/train/angry/Training_3908.jpg")
img.show()
